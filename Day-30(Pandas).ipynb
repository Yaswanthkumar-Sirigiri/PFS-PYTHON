# %%
pip install pandas

# %%
import pandas as pd

# %%
a = [1,2,3,4,5]
pd.Series(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a = [1.2,3.4,5.6,7.8]
pd.Series(a)
# Out:
# 0    1.2
# 1    3.4
# 2    5.6
# 3    7.8
# dtype: float64

# %%
a = ['a','b']
pd.Series(a)
# Out:
# 0    a
# 1    b
# dtype: str

# %%
a = [2+4j,1+5j]
pd.Series(a)
# Out:
# 0    2.0+4.0j
# 1    1.0+5.0j
# dtype: complex128

# %%
a = [True,False]
pd.Series(a)
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
a = {"names":["Yaswanth","Teja","Priya","Preethi"],"marks":[60,70,80,90]}
pd.DataFrame(a)
# Out:
#       names  marks
# 0  Yaswanth     60
# 1      Teja     70
# 2     Priya     80
# 3   Preethi     90

# %%
a = {"names":["Yaswanth","Teja","priya","python"],
     "subjects":["maths","physics","science","operating_system"],
     "marks":[70,80,90,98],
     "percentages":[8.9,9.9,8.0,7.8]
    }
pd.DataFrame(a)
# Out:
#       names          subjects  marks  percentages
# 0  Yaswanth             maths     70          8.9
# 1      Teja           physics     80          9.9
# 2     priya           science     90          8.0
# 3    python  operating_system     98          7.8

# %%
a = pd.read_csv("SampleData.csv")
a
# Out:
#        Name   Subjects  Marks
# 0  Yaswanth      Maths     70
# 1      Teja      Maths     80
# 2     Priya    Physics     90
# 3      Ramu    Physics     89
# 4    Rakesh  Chemistry     95

# %%
a.columns
# Out:
# Index(['Name', 'Subjects', 'Marks'], dtype='str')

# %%
a.shape
# Out:
# (5, 3)

# %%
a.info
# Out:
# <bound method DataFrame.info of        Name   Subjects  Marks
# 0  Yaswanth      Maths     70
# 1      Teja      Maths     80
# 2     Priya    Physics     90
# 3      Ramu    Physics     89
# 4    Rakesh  Chemistry     95>

# %%
data = pd.read_csv("fifa.csv")
data
# Out:
#       player_id       player_name  age nationality   team  jersey_number  \
# 0        P00055        Rodri Fati   26     Spanish  Spain              3
# 1        P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2        P00066        Gavi Ramos   18     Spanish  Spain             14
# 3        P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4        P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
# ...         ...               ...  ...         ...    ...            ...
# 54595    P00996       Amir Younis   28       Iraqi   Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi   Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi   Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi   Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi   Iraq              1
#
#          position  height_cm  weight_kg preferred_foot  ... possession_impact  \
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of       player_id       player_name  age nationality   team  jersey_number  \
# 0        P00055        Rodri Fati   26     Spanish  Spain              3
# 1        P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2        P00066        Gavi Ramos   18     Spanish  Spain             14
# 3        P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4        P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
# ...         ...               ...  ...         ...    ...            ...
# 54595    P00996       Amir Younis   28       Iraqi   Iraq              8
# 54596    P01006  Safaa Al-Khafaji   20       Iraqi   Iraq             18
# 54597    P01008     Ahmed Hussein   26       Iraqi   Iraq             20
# 54598    P00991     Ibrahim Mhawi   30       Iraqi   Iraq              3
# 54599    P00989  Mohannad Hussein   27       Iraqi   Iraq              1
#
# ...

# %%
data.columns
# Out:
# Index(['player_id', 'player_name', 'age', 'nationality', 'team',
#        'jersey_number', 'position', 'height_cm', 'weight_kg', 'preferred_foot',
#        'club_name', 'market_value_eur', 'match_id', 'match_date', 'stadium',
#        'city', 'opponent_team', 'tournament_stage', 'match_result',
#        'goals_team', 'goals_opponent', 'minutes_played', 'goals', 'assists',
#        'shots', 'shots_on_target', 'expected_goals_xg', 'expected_assists_xa',
#        'key_passes', 'successful_passes', 'total_passes', 'pass_accuracy',
#        'dribbles_attempted', 'successful_dribbles', 'crosses',
#        'successful_crosses', 'tackles', 'interceptions', 'clearances',
#        'blocks', 'aerial_duels_won', 'aerial_duels_lost', 'recoveries',
#        'defensive_actions', 'fouls_committed', 'fouls_suffered',
#        'yellow_cards', 'red_cards', 'offsides', 'saves', 'save_percentage',
#        'punches', 'clean_sheet', 'goals_conceded', 'penalty_saves',
# ...

# %%
data.head()
# Out:
#   player_id       player_name  age nationality   team  jersey_number  \
# 0    P00055        Rodri Fati   26     Spanish  Spain              3
# 1    P00070   Ansu Le Normand   19     Spanish  Spain             18
# 2    P00066        Gavi Ramos   18     Spanish  Spain             14
# 3    P00073     Pedro Cubarsi   20     Spanish  Spain             21
# 4    P00059  Alvaro Oyarzabal   23     Spanish  Spain              7
#
#      position  height_cm  weight_kg preferred_foot  ... possession_impact  \
# 0  Goalkeeper        195         75           Left  ...               1.1
# 1  Midfielder        178         75          Right  ...               3.5
# 2  Midfielder        177         72           Left  ...              15.3
# 3     Forward        182         74          Right  ...               1.2
# 4    Defender        191         81           Left  ...               6.2
#
#    pressure_resistance creativity_score consistency_score  \
# ...

# %%
data.shape
# Out:
# (54600, 75)

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.11.1-cp314-cp314-win_amd64.whl.metadata (80 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.63.0-cp314-cp314-win_amd64.whl.metadata (121 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached matplotlib-3.11.1-cp314-cp314-win_amd64.whl (9.5 MB)
# Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.63.0-cp314-cp314-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl (7.2 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# ...
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = [2,4,5,6,7]
y = [6,7,8,9,10]
z = [4,5,6,7,8]
plt.plot(x,y)
plt.show()

# %%
plt.subplot(2,2,1)
plt.title("Graph-1")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(x,y)

plt.subplot(2,2,2)
plt.title("Graph-2")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(x,y)
plt.show()

# %%
plt.subplot(2,2,3)
plt.title("Graph-3")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(x,y)

plt.subplot(2,2,4)
plt.title("Graph-4")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(x,y)
plt.show()
